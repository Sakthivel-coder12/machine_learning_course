# %%
# !pip install gensim
# Out:
# ...
#    ---------------------------------------- 0.0/24.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/24.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/24.0 MB ? eta -:--:--
#     --------------------------------------- 0.5/24.0 MB 799.2 kB/s eta 0:00:30
#     --------------------------------------- 0.5/24.0 MB 799.2 kB/s eta 0:00:30
#    - -------------------------------------- 0.8/24.0 MB 671.3 kB/s eta 0:00:35
#    - -------------------------------------- 1.0/24.0 MB 680.3 kB/s eta 0:00:34
#    - -------------------------------------- 1.0/24.0 MB 680.3 kB/s eta 0:00:34
#    -- ------------------------------------- 1.3/24.0 MB 692.1 kB/s eta 0:00:33
#    -- ------------------------------------- 1.6/24.0 MB 735.9 kB/s eta 0:00:31
# ...

# %%
import gensim

# %%
import gensim.downloader as api
wv = api.load('word2vec-google-news-300')
vec_king = wv['king']
# Out:
# [========================--------------------------] 49.3% 820.0/1662.8MB downloaded
# ---------------------------------------------------------------------------
# ContentTooShortError                      Traceback (most recent call last)
# Cell In[3], line 2
#       1 import gensim.downloader as api
# ----> 2 wv = api.load('word2vec-google-news-300')
#       3 vec_king = wv['king']
#
# File c:\Users\sakth\OneDrive\Desktop\annclassification\dl\lib\site-packages\gensim\downloader.py:496, in load(name, return_path)
#     494 path = os.path.join(folder_dir, file_name)
#     495 if not os.path.exists(folder_dir):
# --> 496     _download(name)
#     498 if return_path:
#     499     return path
#
# File c:\Users\sakth\OneDrive\Desktop\annclassification\dl\lib\site-packages\gensim\downloader.py:396, in _download(name)
#     394 fname = "{fname}.gz".format(fname=name)
#     395 dst_path = os.path.join(tmp_dir, fname)
# --> 396 urllib.urlretrieve(url_data, dst_path, reporthook=_progress)
# ...
